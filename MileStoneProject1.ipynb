# %%
from IPython.display import clear_output
clear_output()

# %%
# printing the board
def print_board(board):
    clear_output()
    print(board[7] + '|' + board[8] + '|' + board[9])
   # print('-','-','-')
    print(board[4] + '|' + board[5] + '|' + board[6])
  #  print('-','-','-')
    print(board[1] + '|' + board[2] + '|' + board[3])

# %%
board = [' ',' ',' ',' ',' ',' ',' ',' ',' ',' ']
print_board(board)

# %%
# checking the win status

def win_check(board,mark):
    return ((board[7] == mark and board[8] == mark and board[9] == mark) or # row1
            (board[4] == mark and board[5] == mark and board[6] == mark) or  # row2
    (board[1] == mark and board[2] == mark and board[3] == mark) or  #row3
    (board[7] == mark and board[4] == mark and board[1] == mark) or  # col1
    (board[8] == mark and board[5] == mark and board[2] == mark) or  # col2
    (board[9] == mark and board[6] == mark and board[3] == mark) or  # col3
    (board[7] == mark and board[5] == mark and board[3] == mark) or  # diagonal
    (board[1] == mark and board[5] == mark and board[9] == mark))  # diagonal

# %%
# checking for tie
def tie(board):

    for i in range(1,10):
        if space_check(board,i):
            return False
    # Board is full if we return True or Board is not full

    return True

# %%
def space_check(board,i):
    return board[i] == ' '

# %%
# selecting the player
def select_player():
    choice = input('How wants to start, Player1 or Player2')
    player1 = ''
    player2 = ''
    if choice == 'Player1' or choice == '1':
        player1 = (input('Select your symbol, X or O')).upper()
        if player1 == 'X':
            player2 = 'O'
        else:
            player2 = 'X'
    return (player1,player2)

# %%
start_game()
# Out:
# O| |X
#  | |
# O| |X
# Player O choose your position(1-9) 4
# Player O won the match

# %%
# staring the game
def game_on(player1,player2):
    board = [' ']*10

  #  print_board(board)
    x = True
    while x:
        position = choose_position(board,player1)
        board[position] = player1
      #  print_board(board)
        if win_check(board,player1) or tie(board):
            if win_check(board,player1): 
                print_board(board)
                print('Player {} won the match'.format(player1))
                board = [' ',' ',' ',' ',' ',' ',' ',' ',' ',' ']
                break
            else:
                print_board(board)
                print('Tie!')
                board = [' ',' ',' ',' ',' ',' ',' ',' ',' ',' ']
                break
        else:
            position = choose_position(board,player2)
            board[position] = player2
        #    print_board(board)
            if win_check(board,player2) or tie(board):
                if win_chekc(board,player2):  
                    print_board(board)
                    print('Player {} won the match'.format(player2))
                    board = [' ',' ',' ',' ',' ',' ',' ',' ',' ',' ']
                    break  
                else:
                    print_board(board)
                    print('Tie!')
                    board = [' ',' ',' ',' ',' ',' ',' ',' ',' ',' ']
                    break

# %%
# choose position

def choose_position(board,player):
    print_board(board)
    position = int(input('Player {} choose your position(1-9)'.format(player)))
    if board[position] != ' ':
        
        print('Wrong position, try again!')
        return choose_position(board,player)

    else:
        return position

# %%
# starting the game
def start_game():
    print('Welcome to Tic Tac Toe')

    player1,player2 = select_player()
    game_on(player1,player2)
